# %%
import pandas as pd

# %%
matches=matches['winner'].isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 matches=matches['winner'].isnull().sum()
#
# IndexError: invalid index to scalar variable.

# %%
print(matches)
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
matches=matches.dropna(subset=['winner'])

# %%
matches.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
matches['team2'].unique()
# Out:
# <StringArray>
# [      'Kolkata Knight Riders',         'Chennai Super Kings',
#             'Rajasthan Royals', 'Royal Challengers Bangalore',
#              'Deccan Chargers',             'Kings XI Punjab',
#             'Delhi Daredevils',              'Mumbai Indians',
#         'Kochi Tuskers Kerala',               'Pune Warriors',
#          'Sunrisers Hyderabad',     'Rising Pune Supergiants',
#                'Gujarat Lions',      'Rising Pune Supergiant',
#               'Delhi Capitals',                'Punjab Kings',
#               'Gujarat Titans',        'Lucknow Super Giants',
#  'Royal Challengers Bengaluru']
# Length: 19, dtype: str

# %%
matches.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='str')

# %%
matches_df["team1"].unique()
# Out:
# <StringArray>
# ['Royal Challengers Bangalore',                'Punjab Kings',
#               'Delhi Capitals',              'Mumbai Indians',
#        'Kolkata Knight Riders',            'Rajasthan Royals',
#              'Deccan Chargers',         'Chennai Super Kings',
#         'Kochi Tuskers Kerala',               'Pune Warriors',
#          'Sunrisers Hyderabad',               'Gujarat Lions',
#      'Rising Pune Supergiants',      'Rising Pune Supergiant',
#         'Lucknow Super Giants',              'Gujarat Titans',
#  'Royal Challengers Bengaluru']
# Length: 17, dtype: str

# %%
matches_df.replace('Delhi Daredevils','Delhi Capitals',inplace=True)
# Out:
#             city                        team1                        team2  \
# 0      Bangalore  Royal Challengers Bangalore        Kolkata Knight Riders
# 1     Chandigarh                 Punjab Kings          Chennai Super Kings
# 2          Delhi               Delhi Capitals             Rajasthan Royals
# 3         Mumbai               Mumbai Indians  Royal Challengers Bangalore
# 4        Kolkata        Kolkata Knight Riders              Deccan Chargers
# ...          ...                          ...                          ...
# 1090   Hyderabad                 Punjab Kings          Sunrisers Hyderabad
# 1091   Ahmedabad          Sunrisers Hyderabad        Kolkata Knight Riders
# 1092   Ahmedabad  Royal Challengers Bengaluru             Rajasthan Royals
# 1093     Chennai          Sunrisers Hyderabad             Rajasthan Royals
# 1094     Chennai          Sunrisers Hyderabad        Kolkata Knight Riders
#
# ...

# %%
matches_df.replace('Kings XI Punjab','Punjab Kings',inplace=True)
# Out:
#             city                        team1                        team2  \
# 0      Bangalore  Royal Challengers Bangalore        Kolkata Knight Riders
# 1     Chandigarh                 Punjab Kings          Chennai Super Kings
# 2          Delhi             Delhi Daredevils             Rajasthan Royals
# 3         Mumbai               Mumbai Indians  Royal Challengers Bangalore
# 4        Kolkata        Kolkata Knight Riders              Deccan Chargers
# ...          ...                          ...                          ...
# 1090   Hyderabad                 Punjab Kings          Sunrisers Hyderabad
# 1091   Ahmedabad          Sunrisers Hyderabad        Kolkata Knight Riders
# 1092   Ahmedabad  Royal Challengers Bengaluru             Rajasthan Royals
# 1093     Chennai          Sunrisers Hyderabad             Rajasthan Royals
# 1094     Chennai          Sunrisers Hyderabad        Kolkata Knight Riders
#
# ...

# %%
matches.shape
# Out:
# (1095, 20)

# %%
type(matches)
# Out:
# numpy.int64

# %%
print(matches.shape)
# Out:
# (1090, 20)

# %%
print(matches_df)
# Out:
#        season        city                        team1  \
# 0     2007/08   Bangalore  Royal Challengers Bangalore
# 1     2007/08  Chandigarh              Kings XI Punjab
# 2     2007/08       Delhi             Delhi Daredevils
# 3     2007/08      Mumbai               Mumbai Indians
# 4     2007/08     Kolkata        Kolkata Knight Riders
# ...       ...         ...                          ...
# 1090     2024   Hyderabad                 Punjab Kings
# 1091     2024   Ahmedabad          Sunrisers Hyderabad
# 1092     2024   Ahmedabad  Royal Challengers Bengaluru
# 1093     2024     Chennai          Sunrisers Hyderabad
# 1094     2024     Chennai          Sunrisers Hyderabad
#
#                             team2                  toss_winner toss_decision  \
# 0           Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1             Chennai Super Kings          Chennai Super Kings           bat
# ...

# %%
matches_df[["city","team1",
"team2",
"toss_winner",
"toss_decision",
"winner"]]
# Out:
#             city                        team1                        team2  \
# 0      Bangalore  Royal Challengers Bangalore        Kolkata Knight Riders
# 1     Chandigarh              Kings XI Punjab          Chennai Super Kings
# 2          Delhi             Delhi Daredevils             Rajasthan Royals
# 3         Mumbai               Mumbai Indians  Royal Challengers Bangalore
# 4        Kolkata        Kolkata Knight Riders              Deccan Chargers
# ...          ...                          ...                          ...
# 1090   Hyderabad                 Punjab Kings          Sunrisers Hyderabad
# 1091   Ahmedabad          Sunrisers Hyderabad        Kolkata Knight Riders
# 1092   Ahmedabad  Royal Challengers Bengaluru             Rajasthan Royals
# 1093     Chennai          Sunrisers Hyderabad             Rajasthan Royals
# 1094     Chennai          Sunrisers Hyderabad        Kolkata Knight Riders
#
# ...

# %%
matches_df.head()
# Out:
#          city                        team1                        team2  \
# 0   Bangalore  Royal Challengers Bangalore        Kolkata Knight Riders
# 1  Chandigarh              Kings XI Punjab          Chennai Super Kings
# 2       Delhi             Delhi Daredevils             Rajasthan Royals
# 3      Mumbai               Mumbai Indians  Royal Challengers Bangalore
# 4     Kolkata        Kolkata Knight Riders              Deccan Chargers
#
#                    toss_winner toss_decision                       winner
# 0  Royal Challengers Bangalore         field        Kolkata Knight Riders
# 1          Chennai Super Kings           bat          Chennai Super Kings
# 2             Rajasthan Royals           bat             Delhi Daredevils
# 3               Mumbai Indians           bat  Royal Challengers Bangalore
# 4              Deccan Chargers           bat        Kolkata Knight Riders

# %%
matches_df.isnull().sum()
# Out:
# city             51
# team1             0
# team2             0
# toss_winner       0
# toss_decision     0
# winner            5
# dtype: int64

# %%
matches_df.shape
# Out:
# (1095, 6)

# %%
print(matches_df)
# Out:
#             city                        team1                        team2  \
# 0      Bangalore  Royal Challengers Bangalore        Kolkata Knight Riders
# 1     Chandigarh              Kings XI Punjab          Chennai Super Kings
# 2          Delhi             Delhi Daredevils             Rajasthan Royals
# 3         Mumbai               Mumbai Indians  Royal Challengers Bangalore
# 4        Kolkata        Kolkata Knight Riders              Deccan Chargers
# ...          ...                          ...                          ...
# 1090   Hyderabad                 Punjab Kings          Sunrisers Hyderabad
# 1091   Ahmedabad          Sunrisers Hyderabad        Kolkata Knight Riders
# 1092   Ahmedabad  Royal Challengers Bengaluru             Rajasthan Royals
# 1093     Chennai          Sunrisers Hyderabad             Rajasthan Royals
# 1094     Chennai          Sunrisers Hyderabad        Kolkata Knight Riders
#
# ...

# %%
matches_df=matches_df.fillna({"city": "unknown"})

# %%
deliveries = pd.read_csv("../data/deliveries.csv")

# %%
matches_df.isnull().sum()
# Out:
# city             51
# team1             0
# team2             0
# toss_winner       0
# toss_decision     0
# winner            0
# dtype: int64

# %%
matches=pd.read_csv("../data/matches.csv")

# %%
matches_df = matches_df.dropna(subset=["winner"])

# %%
matches_df.isnull().sum()
# Out:
# city             51
# team1             0
# team2             0
# toss_winner       0
# toss_decision     0
# winner            5
# dtype: int64

# %%
matches_df.isnull().sum()
# Out:
# city             0
# team1            0
# team2            0
# toss_winner      0
# toss_decision    0
# winner           0
# dtype: int64

# %%
matches_df.value_counts()
# Out:
# city        team1                        team2                  toss_winner          toss_decision  winner
# Bangalore   Royal Challengers Bangalore  Mumbai Indians         Mumbai Indians       field          Mumbai Indians           5
# Mumbai      Mumbai Indians               Delhi Daredevils       Delhi Daredevils     field          Mumbai Indians           4
#                                          Kolkata Knight Riders  Mumbai Indians       field          Mumbai Indians           4
# Kolkata     Kolkata Knight Riders        Rajasthan Royals       Rajasthan Royals     field          Rajasthan Royals         4
# Chandigarh  Kings XI Punjab              Rajasthan Royals       Rajasthan Royals     field          Kings XI Punjab          4
#                                                                                                                             ..
# ...

# %%
matches_df.fillna({"city": "Unknown"})
# Out:
#             city                        team1                        team2  \
# 0      Bangalore  Royal Challengers Bangalore        Kolkata Knight Riders
# 1     Chandigarh              Kings XI Punjab          Chennai Super Kings
# 2          Delhi             Delhi Daredevils             Rajasthan Royals
# 3         Mumbai               Mumbai Indians  Royal Challengers Bangalore
# 4        Kolkata        Kolkata Knight Riders              Deccan Chargers
# ...          ...                          ...                          ...
# 1090   Hyderabad                 Punjab Kings          Sunrisers Hyderabad
# 1091   Ahmedabad          Sunrisers Hyderabad        Kolkata Knight Riders
# 1092   Ahmedabad  Royal Challengers Bengaluru             Rajasthan Royals
# 1093     Chennai          Sunrisers Hyderabad             Rajasthan Royals
# 1094     Chennai          Sunrisers Hyderabad        Kolkata Knight Riders
#
# ...

# %%
# Out:
#             city                        team1                        team2  \
# 0      Bangalore  Royal Challengers Bangalore        Kolkata Knight Riders
# 1     Chandigarh              Kings XI Punjab          Chennai Super Kings
# 2          Delhi             Delhi Daredevils             Rajasthan Royals
# 3         Mumbai               Mumbai Indians  Royal Challengers Bangalore
# 4        Kolkata        Kolkata Knight Riders              Deccan Chargers
# ...          ...                          ...                          ...
# 1090   Hyderabad                 Punjab Kings          Sunrisers Hyderabad
# 1091   Ahmedabad          Sunrisers Hyderabad        Kolkata Knight Riders
# 1092   Ahmedabad  Royal Challengers Bengaluru             Rajasthan Royals
# 1093     Chennai          Sunrisers Hyderabad             Rajasthan Royals
# 1094     Chennai          Sunrisers Hyderabad        Kolkata Knight Riders
#
# ...
