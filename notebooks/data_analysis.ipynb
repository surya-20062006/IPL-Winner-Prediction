# %%
current_score_df = match_delivery.groupby(
    'match_id'
).cumsum()['total_runs']

match_delivery['current_score'] = current_score_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 current_score_df = match_delivery.groupby(
#       2     'match_id'
# ----> 3 ).cumsum()['total_runs']
#       4
#       5 match_delivery['current_score'] = current_score_df
#
# File c:\Users\SURYA\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:5351, in GroupBy.cumsum(self, numeric_only, *args, **kwargs)
#    5291 """
#    5292 Cumulative sum for each group.
#    5293
#    (...)   5348 lion      6   9
#    5349 """
#    5350 nv.validate_groupby_func("cumsum", args, kwargs, ["skipna"])
# -> 5351 return self._cython_transform("cumsum", numeric_only, **kwargs)
#
# File c:\Users\SURYA\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\generic.py:2539, in DataFrameGroupBy._cython_transform(self, how, numeric_only, **kwargs)
# ...

# %%
print(match_delivery.dtypes)
# Out:
# match_id            int64
# inning              int64
# batting_team          str
# bowling_team          str
# over                int64
# ball                int64
# batter                str
# bowler                str
# non_striker           str
# batsman_runs        int64
# extra_runs          int64
# total_runs          int64
# extras_type           str
# is_wicket           int64
# player_dismissed    int64
# dismissal_kind        str
# fielder               str
# id                  int64
# winner                str
# target              int64
# wickets_left        int64
# dtype: object

# %%
print(match_delivery.head())
# Out:
#      match_id  inning                 batting_team           bowling_team  \
# 124    335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 125    335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 126    335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 127    335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 128    335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
#
#      over  ball    batter    bowler non_striker  batsman_runs  ...  \
# 124     0     1  R Dravid  AB Dinda    W Jaffer             1  ...
# 125     0     2  W Jaffer  AB Dinda    R Dravid             0  ...
# 126     0     3  W Jaffer  AB Dinda    R Dravid             0  ...
# 127     0     4  W Jaffer  AB Dinda    R Dravid             1  ...
# 128     0     5  R Dravid  AB Dinda    W Jaffer             1  ...
#
#      total_runs  extras_type is_wicket  player_dismissed  dismissal_kind  \
# ...

# %%
final_df.head()

# %%
groupby(... )['total_runs'].cumsum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 groupby(... )['total_runs'].cumsum()
#
# NameError: name 'groupby' is not defined

# %%
final_df.head()

# %%
match_delivery['current_score'] = (
    match_delivery
    .groupby('match_id')['total_runs']
    .cumsum()
)

# %%
final_df.head()

# %%
groupby(... )['total_runs'].cumsum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 groupby(... )['total_runs'].cumsum()
#
# NameError: name 'groupby' is not defined

# %%
match_delivery['current_score'] = (
    match_delivery
    .groupby('match_id')['total_runs']
    .cumsum()
)

# %%
match_delivery[['total_runs', 'current_score']].head()
# Out:
#      total_runs  current_score
# 124           1              1
# 125           1              2
# 126           0              2
# 127           1              3
# 128           1              4

# %%
match_delivery['runs_left'] = (
    match_delivery['target']
    - match_delivery['current_score']
)

# %%
match_delivery['balls_left'] = (
    120 - (
        (match_delivery['over'] - 1) * 6
        + match_delivery['ball']
    )
)

# %%
print(match_delivery.columns)
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder', 'id', 'winner', 'target', 'wickets_left',
#        'current_score', 'runs_left', 'balls_left'],
#       dtype='str')

# %%
match_delivery['current_run_rate'] = (
    match_delivery['current_score'] * 6
) / (
    120 - match_delivery['balls_left']
)

# %%
match_delivery['required_run_rate'] = (
    match_delivery['runs_left'] * 6
) / (
    match_delivery['balls_left']
)

# %%
match_delivery['result'] = (
    match_delivery['batting_team']
    == match_delivery['winner']
).astype(int)

# %%
print(match_delivery.columns)
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder', 'id', 'winner', 'target', 'wickets_left',
#        'current_score', 'runs_left', 'balls_left', 'current_run_rate',
#        'required_run_rate', 'result'],
#       dtype='str')

# %%
print(match_delivery.columns)
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder', 'id', 'winner', 'target', 'wickets_left',
#        'current_score', 'runs_left', 'balls_left', 'current_run_rate',
#        'required_run_rate', 'result'],
#       dtype='str')

# %%
final_df = match_delivery[
    [
        'batting_team',
        'bowling_team',
        'runs_left',
        'balls_left',
        'wickets_left',
        'target',
        'current_run_rate',
        'required_run_rate',
        'result'
    ]
]

# %%
final_df.head()
# Out:
#                     batting_team           bowling_team  runs_left  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders        221
# 125  Royal Challengers Bangalore  Kolkata Knight Riders        220
# 126  Royal Challengers Bangalore  Kolkata Knight Riders        220
# 127  Royal Challengers Bangalore  Kolkata Knight Riders        219
# 128  Royal Challengers Bangalore  Kolkata Knight Riders        218
#
#      balls_left  wickets_left  target  current_run_rate  required_run_rate  \
# 124         125            10     222              -1.2          10.608000
# 125         124            10     222              -3.0          10.645161
# 126         123            10     222              -4.0          10.731707
# 127         122            10     222              -9.0          10.770492
# 128         121            10     222             -24.0          10.809917
#
#      result
# 124       0
# 125       0
# 126       0
# 127       0
# 128       0

# %%
print(final_df.shape)
# Out:
# (125741, 9)

# %%
print(final_df.isnull().sum())
# Out:
# batting_team          0
# bowling_team          0
# runs_left             0
# balls_left            0
# wickets_left          0
# target                0
# current_run_rate     35
# required_run_rate     0
# result                0
# dtype: int64

# %%
final_df = final_df.dropna()

# %%
print(final_df.isnull().sum())
# Out:
# batting_team         0
# bowling_team         0
# runs_left            0
# balls_left           0
# wickets_left         0
# target               0
# current_run_rate     0
# required_run_rate    0
# result               0
# dtype: int64

# %%
final_df.to_csv("../data/final_df.csv", index=False)

# %%
final_df.head()
# Out:
#                     batting_team           bowling_team  runs_left  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders        221
# 125  Royal Challengers Bangalore  Kolkata Knight Riders        220
# 126  Royal Challengers Bangalore  Kolkata Knight Riders        220
# 127  Royal Challengers Bangalore  Kolkata Knight Riders        219
# 128  Royal Challengers Bangalore  Kolkata Knight Riders        218
#
#      balls_left  wickets_left  target  current_run_rate  required_run_rate  \
# 124         125            10     222              -1.2          10.608000
# 125         124            10     222              -3.0          10.645161
# 126         123            10     222              -4.0          10.731707
# 127         122            10     222              -9.0          10.770492
# 128         121            10     222             -24.0          10.809917
#
#      result
# 124       0
# 125       0
# 126       0
# 127       0
# 128       0

# %%
print(final_df.shape)
# Out:
# (125706, 9)

# %%
print(final_df.isnull().sum())
# Out:
# batting_team         0
# bowling_team         0
# runs_left            0
# balls_left           0
# wickets_left         0
# target               0
# current_run_rate     0
# required_run_rate    0
# result               0
# dtype: int64

# %%
final_df.to_csv("../data/final_df.csv", index=False)

# %%
current_run_rate = (current_score * 6) / (120 - balls_left)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 current_run_rate = (current_score * 6) / (120 - balls_left)
#
# NameError: name 'current_score' is not defined

# %%
import numpy as np

print(final_df.isin([np.inf, -np.inf]).sum())
# Out:
# batting_team            0
# bowling_team            0
# runs_left               0
# balls_left              0
# wickets_left            0
# target                  0
# current_run_rate     1057
# required_run_rate       0
# result                  0
# dtype: int64

# %%
import numpy as np

final_df.replace(
    [np.inf, -np.inf],
    np.nan,
    inplace=True
)
# Out:
#                        batting_team           bowling_team  runs_left  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders        221
# 125     Royal Challengers Bangalore  Kolkata Knight Riders        220
# 126     Royal Challengers Bangalore  Kolkata Knight Riders        220
# 127     Royal Challengers Bangalore  Kolkata Knight Riders        219
# 128     Royal Challengers Bangalore  Kolkata Knight Riders        218
# ...                             ...                    ...        ...
# 260915        Kolkata Knight Riders    Sunrisers Hyderabad          3
# 260916        Kolkata Knight Riders    Sunrisers Hyderabad          2
# 260917        Kolkata Knight Riders    Sunrisers Hyderabad          1
# 260918        Kolkata Knight Riders    Sunrisers Hyderabad          0
# 260919        Kolkata Knight Riders    Sunrisers Hyderabad         -1
#
#         balls_left  wickets_left  target  current_run_rate  required_run_rate  \
# ...

# %%
final_df.dropna(inplace=True)

# %%
print(final_df.isnull().sum())
# Out:
# batting_team         0
# bowling_team         0
# runs_left            0
# balls_left           0
# wickets_left         0
# target               0
# current_run_rate     0
# required_run_rate    0
# result               0
# dtype: int64

# %%
print(final_df.isin([np.inf, -np.inf]).sum())
# Out:
# batting_team         0
# bowling_team         0
# runs_left            0
# balls_left           0
# wickets_left         0
# target               0
# current_run_rate     0
# required_run_rate    0
# result               0
# dtype: int64

# %%
final_df.to_csv("../data/final_df.csv", index=False)

# %% [markdown]
# python src/train_model.py
